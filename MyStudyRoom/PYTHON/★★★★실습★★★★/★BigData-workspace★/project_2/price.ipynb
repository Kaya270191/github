# %%
import pandas as pd

# %%
priceGarbage=pd.read_csv('./data/쓰레기관리비.csv',  encoding='euc-kr')

# %%
priceGarbage
# Out:
#     Unnamed: 0 Unnamed: 1     Unnamed: 2           소계        매립시설  \
# 0           전국         합계  4,646,890,762  226,592,005  63,444,140
# 1           서울         소계    731,639,315      926,768           0
# 2          NaN        종로구     27,159,409            0           0
# 3          NaN         중구     11,632,733            0           0
# 4          NaN        용산구     32,825,500            0           0
# ..         ...        ...            ...          ...         ...
# 252        NaN        합천군      4,768,969       25,197      16,333
# 253         제주         소계    237,248,934   92,882,364  20,274,483
# 254        NaN        제주도     95,661,467   90,537,351  20,274,483
# 255        NaN        제주시     96,240,592            0           0
# 256        NaN       서귀포시     45,346,875    2,345,013           0
#
#             기타시설           소계.1            인건비       차량운영비       장비구입비  \
# 0    163,147,865  4,420,298,757  1,038,599,883  68,794,880  97,570,692
# ...

# %%
def fullName(name):
    global sidoname
    if(pd.isna(name)==0):
        sidoname=name
        return sidoname
    else:
        return sidoname

# %%
priceGarbage['Unnamed: 0']=priceGarbage['Unnamed: 0'].apply(fullName)
priceGarbage['Unnamed: 0'].value_counts()
# Out:
# 경기    32
# 서울    26
# 경북    24
# 전남    24
# 경남    20
# 강원    20
# 부산    17
# 충남    17
# 전북    15
# 인천    12
# 충북    12
# 대구    10
# 광주     7
# 대전     7
# 울산     7
# 제주     4
# 세종     2
# 전국     1
# Name: Unnamed: 0, dtype: int64

# %%
priceGarbage[140:190]
# Out:
#     Unnamed: 0 Unnamed: 1   Unnamed: 2          소계        매립시설       기타시설  \
# 140         강원        양양군    8,605,603     919,212     243,562    675,650
# 141         충북         소계  134,391,158  18,126,178  14,178,231  3,947,947
# 142         충북        청주시   56,282,359  16,666,277  13,193,972  3,472,305
# 143         충북        충주시   23,643,143           0           0          0
# 144         충북        제천시    7,874,071           0           0          0
# 145         충북        보은군    4,896,311           0           0          0
# 146         충북        옥천군    5,935,008     472,934           0    472,934
# 147         충북        영동군    5,614,000           0           0          0
# 148         충북        증평군    4,341,113           0           0          0
# 149         충북        진천군   11,304,948     984,259     984,259          0
# 150         충북        괴산군      898,679       2,708           0      2,708
# 151         충북        음성군   10,486,968           0           0          0
# ...
